# %% [markdown]
# 1. Import dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.26.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: pandas in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.1.4)
# Requirement already satisfied: torch>=1.13 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: cloudpickle in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: matplotlib in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: pillow; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (10.1.0)
# Requirement already satisfied: rich; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (13.7.0)
# Requirement already satisfied: shimmy[atari]~=1.3.0; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: opencv-python; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Requirement already satisfied: tqdm; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: tensorboard>=2.9.1; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: psutil; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (5.9.7)
# Requirement already satisfied: pygame; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1; extra == "extra" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: jinja2 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: filelock in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: fsspec in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.12.2)
# Requirement already satisfied: networkx in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.46.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (6.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from rich; extra == "extra"->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from rich; extra == "extra"->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: ale-py~=0.8.1; extra == "atari" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tqdm; extra == "extra"->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.60.0)
# Requirement already satisfied: six>1.9 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.25.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (49.2.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (4.23.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: click in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: AutoROM.accept-rom-license; extra == "accept-rom-license" in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch>=1.13->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich; extra == "extra"->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.2.2)
# WARNING: You are using pip version 20.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'c:\users\bruno\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import os
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# 2. Load Environment

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1,episodes+1):
    state = env.reset()
    terminated = False
    score = 0

    while not terminated:
        env.render()
        action = env.action_space.sample() #0 ou 1, Discrete
        observation, reward, terminated, truncated, info = env.step(action)
        score += reward
    print('Episode:{} Score: {}'.format(episode,score,reward))
#env.close()
# Out:
# Episode:1 Score: 13.0
# Episode:2 Score: 14.0
# Episode:3 Score: 24.0
# Episode:4 Score: 15.0
# Episode:5 Score: 14.0

# %% [markdown]
# Train RL Model

# %%
log_path = os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
env.close()
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 1891 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1308         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0048570796 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.27         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 17.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031545581 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.63         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 58.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017752578 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 18.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1128         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007270687 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.918        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000214     |
# |    value_loss           | 5.89         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009147366 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.478       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010616454 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00945    |
# |    value_loss           | 0.994       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1090         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060689654 |
# |    clip_fraction        | 0.072        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.18         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 1.1          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006330478 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0634      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 0.336       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0064767883 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0019      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 0.165        |
# ------------------------------------------

# %% [markdown]
# Save and Reload Model

# %%
PPO_Path = os.path.join('Training','Saved Models','PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path,env=env)

# %% [raw]
# Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render = True)
# Out:
# (500.0, 0.0)

# %% [raw]
# Test Model

# %%
env.close()

# %%
episodes = 5
for episode in range(1,episodes+1):
    obs = env.reset()
    terminated = False
    score = 0

    while not terminated:
        env.render()
        action,_ = model.predict(obs) #Using model
        obs, reward, terminated, info = env.step(action)
        score += reward
    print('Episode:{} Score: {}'.format(episode,score))
#env.close()
# Out:
# Episode:1 Score: [500.]
# Episode:2 Score: [500.]
# Episode:3 Score: [500.]
# Episode:4 Score: [500.]
# Episode:5 Score: [500.]

# %%
obs = env.reset()

# %%
model.predict(obs)
# Out:
# (array([0], dtype=int64), None)

# %%
env.action_sample.sample()

# %% [raw]
# Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_8')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_8'

# %% [markdown]
# ir no diretório do model  via cdm e digitar "tensorboard --logdir-.". Vai abrir um localhost:6006

# %% [raw]
# Adding a callback to the training step

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training','Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500,verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback = eval_callback)
# Out:
# Logging to Training\Logs\PPO_10
# -----------------------------
# | time/              |      |
# |    fps             | 1871 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008787589 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00306     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.91        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010397654 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 907          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073990943 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 57.8         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=349.40 +/- 112.27
# Episode length: 349.40 +/- 112.27
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 349         |
# |    mean_reward          | 349         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006357777 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 62.8        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 864   |
# |    iterations      | 5     |
# |    time_elapsed    | 11    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009998815 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 58.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 7            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0020040288 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.61         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 45.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 821        |
# |    iterations           | 8          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00447894 |
# |    clip_fraction        | 0.0329     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.58      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.5       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0054    |
# |    value_loss           | 60.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005882904 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=455.60 +/- 57.00
# Episode length: 455.60 +/- 57.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 456         |
# |    mean_reward          | 456         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.008278669 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00697    |
# |    value_loss           | 48.4        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 785   |
# |    iterations      | 10    |
# |    time_elapsed    | 26    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [raw]
# Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# c:\users\bruno\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\common\policies.py:484: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback = eval_callback)
# Out:
# Logging to Training\Logs\PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 1013 |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012842581 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.0026     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016222028 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 28.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015709091 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# Eval num_timesteps=9520, episode_reward=420.60 +/- 98.90
# Episode length: 420.60 +/- 98.90
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 421         |
# |    mean_reward          | 421         |
# | time/                   |             |
# |    total_timesteps      | 9520        |
# | train/                  |             |
# |    approx_kl            | 0.008346467 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 51.1        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 585   |
# |    iterations      | 5     |
# |    time_elapsed    | 17    |
# |    total_timesteps | 10240 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 568        |
# |    iterations           | 6          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01046642 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.552     |
# |    explained_variance   | 0.604      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.9       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0133    |
# |    value_loss           | 27.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006034344 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 17.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010324955 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009409255 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.7         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# Eval num_timesteps=19520, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 500        |
# |    mean_reward          | 500        |
# | time/                   |            |
# |    total_timesteps      | 19520      |
# | train/                  |            |
# |    approx_kl            | 0.00800962 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.536     |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.5        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 18.4       |
# ----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %% [raw]
# Using an alternate algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback = eval_callback)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2768     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3691     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 205      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3688     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 302      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3652     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3628     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3709     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3889     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 641      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3901     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 758      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3941     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 851      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4022     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 933      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4195     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4301     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4403     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4544     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4759     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4881     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5120     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.198    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5229     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5324     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.114    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5352     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0704   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5463     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1957     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5587     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5543     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5550     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5597     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5548     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5595     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5633     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5643     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5751     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 5836     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5803     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 5808     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5822     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 5876     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 5917     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5936     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5969     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 6002     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 6063     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 6110     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 6157     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 6146     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 6167     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 6218     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 6214     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 6281     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 6269     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 6306     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 6308     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 6316     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 6366     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 6387     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 6340     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 6363     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 6402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 6422     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6443     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6451     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 6411     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 6399     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 6376     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 6366     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 6353     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5985     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 6354     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 6315     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 6336     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 6311     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 6289     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 6266     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 6268     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 6253     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 6259     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 6283     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 6259     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 6241     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 6251     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 6262     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 6251     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 6274     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 6242     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 6280     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 6268     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 6260     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 6271     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 6287     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 6288     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 6303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 6324     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 6332     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 6336     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 6375     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 6382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 6391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 6411     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 6408     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 6404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 6418     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 6432     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 6444     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 6483     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 6479     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 6480     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 6515     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 6503     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 6484     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 6507     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 6503     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 6528     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 6533     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9911     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=16.60 +/- 1.36
# Episode length: 16.60 +/- 1.36
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 16.6     |
# |    mean_reward      | 16.6     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 6338     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 6323     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 6348     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 6371     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 6376     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 6379     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 6414     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 6421     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 6393     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 6388     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 6402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 6427     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 6429     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 6440     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 6457     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 6476     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 6481     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 6508     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 6503     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 6513     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 6508     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 6502     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 6508     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 6501     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 6517     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 6521     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 6527     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 6538     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 6538     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 6557     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12778    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 6552     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 6566     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 6577     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 6579     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 6585     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 6604     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 6601     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 6577     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 6577     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13491    |
# ----------------------------------
# ...
# |    fps              | 6613     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 6617     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 6620     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 6629     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 6627     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 6627     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 6626     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 6632     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 6636     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 6644     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 6646     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 6643     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 6657     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 6651     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 6664     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 6685     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 6682     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 6687     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 6700     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 6686     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 6688     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 6684     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 6664     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 6666     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 6671     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 6672     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 6677     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 6679     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 6683     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 6696     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 6689     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 6697     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 6712     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 6709     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 6709     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 6719     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 6717     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 6721     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 6731     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 6742     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 6735     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 6744     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 6747     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 6750     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 6746     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 6746     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 6750     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 6741     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 6717     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 6723     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19956    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=14.60 +/- 1.02
# Episode length: 14.60 +/- 1.02
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 14.6     |
# |    mean_reward      | 14.6     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------
